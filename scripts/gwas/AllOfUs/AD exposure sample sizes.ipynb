# %% [markdown]
# # Antidepressant exposure sample sizes

# %%
library(readr)
library(dplyr)
library(stringr)
library(ggplot2)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
bucket <- Sys.getenv("WORKSPACE_BUCKET")
billing <- Sys.getenv("GOOGLE_PROJECT")

# %% [markdown]
# ## Exposure phenoypes

# %%
system(str_glue("gsutil -m cp {bucket}/inputs/atc_antidep.* ."))

# %%
pheno <- read_tsv("atc_antidep.pheno")
covar <- read_tsv("atc_antidep.covar")
# Out:
# Rows: 206173 Columns: 5
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: "\t"
# dbl (5): FID, IID, N06A, N06AA, N06AB
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 206161 Columns: 13
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr  (1): gender
# dbl (12): FID, IID, PC1_AVG, PC2_AVG, PC3_AVG, PC4_AVG, PC5_AVG, PC6_AVG, PC...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %% [markdown]
# ## Genetics auxiliary files

# %%
system(str_glue("gsutil -m -u {billing} cp gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/aux/ancestry/ancestry_preds.tsv ."))
system(str_glue("gsutil -m -u {billing} cp gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/aux/qc/flagged_samples.tsv ."))

# %%
ancestry <- read_tsv("ancestry_preds.tsv")
flagged <- read_tsv("flagged_samples.tsv")
# Out:
# Rows: 245394 Columns: 5
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (4): ancestry_pred, probabilities, pca_features, ancestry_pred_other
# dbl (1): research_id
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 549 Columns: 22
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (5): ancestry_pred, probabilities, pca_features, ancestry_pred_other, qc...
# dbl (9): s, snp_count, ins_del_ratio, del_count, ins_count, snp_het_homvar_r...
# lgl (8): fail_snp_count_residual, fail_ins_del_ratio_residual, fail_del_coun...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %% [markdown]
# ## Sample sizes

# %%
pheno_cover_cluster <-
pheno |>
    inner_join(ancestry, by = c("IID" = "research_id")) |>
    inner_join(covar, by = c("FID", "IID")) |>
    select(FID, IID, starts_with("N06A"), ancestry_pred, starts_with("PC"), -pca_features)

# %%
pheno_cover_cluster |>
    count(ancestry_pred, N06A)
# Out:
#    ancestry_pred N06A n
# 1  afr           0    32478
# 2  afr           1    13291
# 3  amr           0    27879
# 4  amr           1     8270
# 5  eas           0     3554
# 6  eas           1      672
# 7  eur           0    72790
# 8  eur           1    43860
# 9  mid           0      621
# 10 mid           1      185
# 11 sas           0     2049
# 12 sas           1      512

# %%
ggplot(mutate(pheno_cover_cluster, N06A = if_else(N06A == 1, true = "Case", false = "Control")),
              aes(x = ancestry_pred, group = N06A, fill = N06A)) +
    geom_bar()
# Out:
# plot without title

# %%
pheno_cover_cluster |>
    count(ancestry_pred, N06AA)
# Out:
#    ancestry_pred N06AA n
# 1  afr           0      42066
# 2  afr           1       3706
# 3  amr           0      33847
# 4  amr           1       2305
# 5  eas           0       4086
# 6  eas           1        140
# 7  eur           0     106054
# 8  eur           1      10602
# 9  mid           0        758
# 10 mid           1         48
# 11 sas           0       2450
# 12 sas           1        111

# %%
pheno_cover_cluster |>
    count(ancestry_pred, N06AB)
# Out:
#    ancestry_pred N06AB n
# 1  afr           0     37853
# 2  afr           1      7919
# 3  amr           0     30949
# 4  amr           1      5203
# 5  eas           0      3795
# 6  eas           1       431
# 7  eur           0     88013
# 8  eur           1     28643
# 9  mid           0       692
# 10 mid           1       114
# 11 sas           0      2231
# 12 sas           1       330

# %% [markdown]
# ## Covariates

# %%
ggplot(pheno_cover_cluster, aes(x = PC1_AVG, y = PC2_AVG)) +
    geom_point() +
    facet_wrap(~ancestry_pred)
# Out:
# plot without title

# %%
clusters <- pheno_cover_cluster |>
    distinct(ancestry_pred) |>
    pull(ancestry_pred)
names(clusters) <- clusters

# %%
n06a_pcs_formula <- as.formula(str_c("N06A ~ ", str_c("PC", 1:10, "_AVG", sep = "", collapse = " + ")))

# %%
n06a_pcs_m_list <-
lapply(clusters, function(clust) {

glm(n06a_pcs_formula,
            family = "binomial",
            data = filter(pheno_cover_cluster, ancestry_pred == clust))
    })

# %%
lapply(n06a_pcs_m_list, summary)
# Out:
# $eur
#
# Call:
# glm(formula = n06a_pcs_formula, family = "binomial", data = filter(pheno_cover_cluster,
#     ancestry_pred == clust))
#
# Coefficients:
#               Estimate Std. Error z value Pr(>|z|)
# (Intercept) -5.076e-01  6.055e-03 -83.822  < 2e-16 ***
# PC1_AVG      6.750e-02  1.087e-02   6.210 5.31e-10 ***
# PC2_AVG      8.684e-02  1.771e-02   4.905 9.35e-07 ***
# PC3_AVG      3.470e-03  8.164e-03   0.425  0.67078
# PC4_AVG      4.997e-02  7.755e-03   6.443 1.17e-10 ***
# PC5_AVG      1.112e-02  8.367e-03   1.329  0.18371
# PC6_AVG      1.537e-02  9.438e-03   1.629  0.10335
# PC7_AVG      2.903e-02  9.405e-03   3.087  0.00202 **
# PC8_AVG      1.195e-02  9.072e-03   1.317  0.18791
# PC9_AVG      9.798e-03  9.075e-03   1.080  0.28029
# PC10_AVG    -3.092e-05  8.860e-03  -0.003  0.99722
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 154461  on 116649  degrees of freedom
# Residual deviance: 154349  on 116639  degrees of freedom
# AIC: 154371
#
# Number of Fisher Scoring iterations: 4
#
#
# $sas
#
# Call:
# glm(formula = n06a_pcs_formula, family = "binomial", data = filter(pheno_cover_cluster,
#     ancestry_pred == clust))
#
# Coefficients:
#              Estimate Std. Error z value Pr(>|z|)
# (Intercept) -1.414144   0.050641 -27.925  < 2e-16 ***
# PC1_AVG      0.147326   0.033426   4.408 1.05e-05 ***
# PC2_AVG      0.044025   0.028544   1.542   0.1230
# PC3_AVG      0.031124   0.014715   2.115   0.0344 *
# PC4_AVG     -0.012817   0.024360  -0.526   0.5988
# PC5_AVG      0.035377   0.023668   1.495   0.1350
# PC6_AVG     -0.006365   0.016628  -0.383   0.7019
# PC7_AVG     -0.035312   0.018873  -1.871   0.0613 .
# PC8_AVG     -0.010517   0.018543  -0.567   0.5706
# PC9_AVG      0.014100   0.017559   0.803   0.4220
# PC10_AVG    -0.017130   0.018735  -0.914   0.3606
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 2562.5  on 2560  degrees of freedom
# Residual deviance: 2530.9  on 2550  degrees of freedom
# AIC: 2552.9
#
# Number of Fisher Scoring iterations: 4
#
#
# $afr
#
# Call:
# glm(formula = n06a_pcs_formula, family = "binomial", data = filter(pheno_cover_cluster,
#     ancestry_pred == clust))
#
# Coefficients:
#               Estimate Std. Error z value Pr(>|z|)
# (Intercept) -0.8948621  0.0103635 -86.348  < 2e-16 ***
# PC1_AVG      0.0336714  0.0096542   3.488 0.000487 ***
# PC2_AVG     -0.0006844  0.0339700  -0.020 0.983926
# PC3_AVG     -0.0150531  0.0153854  -0.978 0.327877
# PC4_AVG      0.0073323  0.0126513   0.580 0.562205
# PC5_AVG      0.0025029  0.0105995   0.236 0.813331
# PC6_AVG      0.0137105  0.0091073   1.505 0.132209
# PC7_AVG     -0.0028350  0.0089272  -0.318 0.750814
# PC8_AVG     -0.0030907  0.0086771  -0.356 0.721696
# PC9_AVG     -0.0104607  0.0087039  -1.202 0.229423
# PC10_AVG    -0.0015537  0.0088264  -0.176 0.860268
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 55152  on 45768  degrees of freedom
# Residual deviance: 55135  on 45758  degrees of freedom
# AIC: 55157
#
# Number of Fisher Scoring iterations: 4
#
#
# $amr
#
# Call:
# glm(formula = n06a_pcs_formula, family = "binomial", data = filter(pheno_cover_cluster,
#     ancestry_pred == clust))
#
# Coefficients:
#              Estimate Std. Error z value Pr(>|z|)
# (Intercept) -1.268314   0.013167 -96.328  < 2e-16 ***
# PC1_AVG     -0.225018   0.007982 -28.191  < 2e-16 ***
# PC2_AVG      0.026280   0.005810   4.523 6.09e-06 ***
# PC3_AVG      0.180145   0.010574  17.036  < 2e-16 ***
# PC4_AVG     -0.076536   0.010441  -7.330 2.30e-13 ***
# PC5_AVG      0.049120   0.014716   3.338 0.000845 ***
# PC6_AVG     -0.027770   0.012079  -2.299 0.021506 *
# PC7_AVG     -0.046737   0.012832  -3.642 0.000270 ***
# PC8_AVG      0.002277   0.012013   0.190 0.849691
# PC9_AVG      0.021175   0.012059   1.756 0.079103 .
# PC10_AVG    -0.028782   0.011743  -2.451 0.014250 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 38881  on 36148  degrees of freedom
# Residual deviance: 37604  on 36138  degrees of freedom
# AIC: 37626
#
# Number of Fisher Scoring iterations: 4
#
#
# $eas
#
# Call:
# glm(formula = n06a_pcs_formula, family = "binomial", data = filter(pheno_cover_cluster,
#     ancestry_pred == clust))
#
# Coefficients:
#              Estimate Std. Error z value Pr(>|z|)
# (Intercept) -1.697940   0.043272 -39.239  < 2e-16 ***
# PC1_AVG      0.038738   0.034827   1.112   0.2660
# PC2_AVG     -0.075636   0.016340  -4.629 3.68e-06 ***
# PC3_AVG      0.026853   0.013812   1.944   0.0519 .
# PC4_AVG     -0.020127   0.017749  -1.134   0.2568
# PC5_AVG     -0.023551   0.015356  -1.534   0.1251
# PC6_AVG      0.010235   0.015581   0.657   0.5112
# PC7_AVG     -0.002641   0.020212  -0.131   0.8960
# PC8_AVG     -0.028728   0.027671  -1.038   0.2992
# PC9_AVG      0.040391   0.020846   1.938   0.0527 .
# PC10_AVG    -0.022143   0.020640  -1.073   0.2834
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 3702.3  on 4225  degrees of freedom
# Residual deviance: 3666.9  on 4215  degrees of freedom
# AIC: 3688.9
#
# Number of Fisher Scoring iterations: 4
#
#
# $mid
#
# Call:
# glm(formula = n06a_pcs_formula, family = "binomial", data = filter(pheno_cover_cluster,
#     ancestry_pred == clust))
#
# Coefficients:
#              Estimate Std. Error z value Pr(>|z|)
# (Intercept) -1.226175   0.085255 -14.382   <2e-16 ***
# PC1_AVG      0.032036   0.057529   0.557   0.5776
# PC2_AVG     -0.080368   0.053009  -1.516   0.1295
# PC3_AVG     -0.038862   0.032779  -1.186   0.2358
# PC4_AVG     -0.045292   0.027023  -1.676   0.0937 .
# PC5_AVG      0.021804   0.023068   0.945   0.3446
# PC6_AVG      0.002408   0.019425   0.124   0.9013
# PC7_AVG     -0.004936   0.020479  -0.241   0.8095
# PC8_AVG     -0.011325   0.019578  -0.578   0.5630
# PC9_AVG     -0.028941   0.020403  -1.419   0.1560
# PC10_AVG    -0.009356   0.019666  -0.476   0.6343
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 868.39  on 805  degrees of freedom
# Residual deviance: 858.17  on 795  degrees of freedom
# AIC: 880.17
#
# Number of Fisher Scoring iterations: 4
