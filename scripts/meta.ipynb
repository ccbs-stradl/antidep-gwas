# %% [markdown]
# # Meta-analysis of antidepressant exposure GWAS

# %% [markdown]
# Conduct GWAS meta-analysis using [Hail](https://hail.is). Import GWAS sumstats in [GWAS VCF](https://github.com/MRCIEU/gwas-vcf-specification) format, which can be read into Hail and understood like any other VCF file. See also [meta-analysis functions from the Pan UK Biobank](https://github.com/atgu/ukbb_pan_ancestry/blob/master/utils/meta_analysis.py).

# %%
import pandas as pd
import hail as hl
hl.init(local='local[8]')
# Out:
# SLF4J: No SLF4J providers were found.
# SLF4J: Defaulting to no-operation (NOP) logger implementation
# SLF4J: See https://www.slf4j.org/codes.html#noProviders for further details.
# SLF4J: Class path contains SLF4J bindings targeting slf4j-api versions 1.7.x or earlier.
# SLF4J: Ignoring binding found at [jar:file:/opt/homebrew/anaconda3/envs/hail/lib/python3.10/site-packages/pyspark/jars/log4j-slf4j-impl-2.17.2.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See https://www.slf4j.org/codes.html#ignoredBindings for an explanation.
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# Running on Apache Spark version 3.3.2
# SparkUI available at http://sakyo.home:4040
# Welcome to
#      __  __     <>__
#     / /_/ /__  __/ /
#    / __  / _ `/ / /
#   /_/ /_/\_,_/_/_/   version 0.2.120-f00f916faf78
# LOGGING: writing to /Users/mark/Work/antidep-gwas/hail-20230802-1016-0.2.120-f00f916faf78.log

# %% [markdown]
# Open all the sumstats tables

# %%
gw = hl.read_matrix_table("mt/N06A.mt")

# %%
list(gw.entry)
# Out:
# ['ES', 'SE', 'LP', 'AF', 'SS', 'EZ', 'SI', 'NC', 'ID']

# %%
gw.s.split("-")
# Out:
# <ArrayExpression of type array<str>>

# %%
samples = gw.s.collect()
meta_df = pd.DataFrame(
    {
    "dataset": samples,
    "group": ["-".join(s.split('-')[1:3]) for s in samples]
    }
)
meta_t = hl.Table.from_pandas(samples_datasets_df, key="dataset")
meta_t.show()
# Out:
# +---------------------+-------------+
# | dataset             | group       |
# +---------------------+-------------+
# | str                 | str         |
# +---------------------+-------------+
# | "BBJ-N06A-EAS"      | "N06A-EAS"  |
# | "FinnGen-N06A-EUR"  | "N06A-EUR"  |
# | "GenScot-N06A-EUR"  | "N06A-EUR"  |
# | "GenScot-N06AA-EUR" | "N06AA-EUR" |
# | "GenScot-N06AB-EUR" | "N06AB-EUR" |
# | "UKB-N06A-AFR"      | "N06A-AFR"  |
# | "UKB-N06A-AMR"      | "N06A-AMR"  |
# | "UKB-N06A-EAS"      | "N06A-EAS"  |
# | "UKB-N06A-EUR"      | "N06A-EUR"  |
# | "UKB-N06A-MID"      | "N06A-MID"  |
# +---------------------+-------------+
# showing top 10 rows

# %% [markdown]
# Annotate sumstats columns with phenotype and cluster group

# %%
gw = gw.annotate_cols(analysis=meta_t[gw.s].group)
gw.analysis.show()
# Out:
# +---------------------+-------------+
# | s                   | analysis    |
# +---------------------+-------------+
# | str                 | str         |
# +---------------------+-------------+
# | "UKB-N06AA-MID"     | "N06AA-MID" |
# | "FinnGen-N06A-EUR"  | "N06A-EUR"  |
# | "UKB-N06A-MID"      | "N06A-MID"  |
# | "UKB-N06A-EAS"      | "N06A-EAS"  |
# | "GenScot-N06AA-EUR" | "N06AA-EUR" |
# | "UKB-N06AB-AFR"     | "N06AB-AFR" |
# | "UKB-N06AB-EUR"     | "N06AB-EUR" |
# | "GenScot-N06A-EUR"  | "N06A-EUR"  |
# | "UKB-N06AB-SAS"     | "N06AB-SAS" |
# | "UKB-N06A-SAS"      | "N06A-SAS"  |
# +---------------------+-------------+
# showing top 10 rows

# %% [markdown]
# Meta-analysis weight for each sumstats entry (IVW)

# %%
# inverse variance weight for each estimate
# sample size weight for other data
mw = gw.annotate_entries(
    ivw=1 / gw.SE ** 2,
    ncw=1 / gw.NC
)

# effect weighted by inverse variance
mw = mw.annotate_entries(
    ES_w=mw.ES * mw.ivw,
    AF_w=mw.AF * mw.ncw,
    SI_w=mw.SI * mw.ncw
)

# %% [markdown]
# Meta-analysis aggregation for each cluster

# %%
ma = mw.group_cols_by(mw.analysis).aggregate(
    ES=(hl.agg.array_sum(mw.ES_w) / hl.agg.array_sum(mw.ivw)).first(),
    SE=hl.map(lambda ivw_sum: hl.sqrt(1 / ivw_sum), hl.agg.array_sum(mw.ivw)).first(),
    NC=hl.agg.array_sum(mw.NC).first(),
    SS=hl.agg.array_sum(mw.SS).first(),
    AF=(hl.agg.array_sum(mw.AF_w) / hl.agg.array_sum(mw.ncw)).first(),
    SI=(hl.agg.array_sum(mw.SI_w) / hl.agg.array_sum(mw.ncw)).first()
)

ma = ma.annotate_entries(
    PP=hl.pchisqtail(ma.ES ** 2 / ma.SE ** 2, df=1)
)

# %%
ma.PP.show()
# Out:
# +---------------+--------------------------------+---------------+
# | locus         | alleles                        | 'N06A-AFR'.PP |
# +---------------+--------------------------------+---------------+
# | locus<GRCh38> | array<str>                     |       float64 |
# +---------------+--------------------------------+---------------+
# | chr1:10177    | ["A","AC"]                     |      8.84e-01 |
# | chr1:10511    | ["G","A"]                      |            NA |
# | chr1:10616    | ["CCGCCGTTGCAAAGGCGCGCCG","C"] |      1.05e-02 |
# | chr1:11008    | ["C","G"]                      |      9.41e-01 |
# | chr1:11012    | ["C","G"]                      |      9.41e-01 |
# | chr1:13110    | ["G","A"]                      |      9.37e-01 |
# | chr1:13116    | ["T","G"]                      |      1.11e-01 |
# | chr1:13118    | ["A","G"]                      |      1.11e-01 |
# | chr1:13273    | ["G","C"]                      |      6.95e-02 |
# | chr1:13289    | ["C","CCT"]                    |            NA |
# +---------------+--------------------------------+---------------+
#
# +---------------+---------------+
# | 'N06A-AMR'.PP | 'N06A-EAS'.PP |
# +---------------+---------------+
# |       float64 |       float64 |
# +---------------+---------------+
# |      1.67e-01 |      2.91e-03 |
# |            NA |            NA |
# |            NA |            NA |
# |      1.84e-01 |      4.52e-01 |
# |      1.84e-01 |      4.52e-01 |
# |      7.74e-01 |      9.84e-01 |
# |      9.46e-01 |      2.08e-01 |
# |      9.46e-01 |      2.08e-01 |
# |      6.51e-01 |      7.76e-01 |
# |            NA |            NA |
# +---------------+---------------+
# showing top 10 rows
# showing the first 3 of 17 columns

# %%
analyses = pd.DataFrame({"analysis": ma.analysis.collect()})
analyses
# Out:
#      analysis
# 0    N06A-AFR
# 1    N06A-AMR
# 2    N06A-EAS
# 3    N06A-EUR
# 4    N06A-MID
# 5    N06A-SAS
# 6   N06AA-AFR
# 7   N06AA-EUR
# 8   N06AA-MID
# 9   N06AA-SAS
# 10  N06AB-AFR
# 11  N06AB-EUR
# 12  N06AB-MID
# 13  N06AB-SAS
# 14  N06AX-AFR
# 15  N06AX-EUR
# 16  N06AX-SAS

# %%
ma.filter_cols(ma.analysis == "N06A-EUR").make_table().flatten().export("meta/ivw-N06A-EUR.tsv.bgz")
# Out:
# 2023-08-02 14:46:22.587 Hail: INFO: merging 63 files totalling 1.0G...+ 1) / 62]
# 2023-08-02 14:46:24.168 Hail: INFO: while writing:
#     meta/ivw-N06A-EUR.tsv.bgz
#   merge time: 1.578s

# %%
ma.filter_cols(ma.analysis == "N06A-EUR").make_table().flatten().show()
# Out:
# +---------------+--------------------------------+---------------+-----------+
# | locus         | alleles                        | rsid          |      qual |
# +---------------+--------------------------------+---------------+-----------+
# | locus<GRCh38> | array<str>                     | str           |   float64 |
# +---------------+--------------------------------+---------------+-----------+
# | chr1:10177    | ["A","AC"]                     | "rs201752861" | -1.00e+01 |
# | chr1:10511    | ["G","A"]                      | "rs534229142" | -1.00e+01 |
# | chr1:10616    | ["CCGCCGTTGCAAAGGCGCGCCG","C"] | "rs376342519" | -1.00e+01 |
# | chr1:11008    | ["C","G"]                      | "rs575272151" | -1.00e+01 |
# | chr1:11012    | ["C","G"]                      | "rs544419019" | -1.00e+01 |
# | chr1:13110    | ["G","A"]                      | "rs540538026" | -1.00e+01 |
# | chr1:13116    | ["T","G"]                      | "rs62635286"  | -1.00e+01 |
# | chr1:13118    | ["A","G"]                      | "rs62028691"  | -1.00e+01 |
# | chr1:13273    | ["G","C"]                      | "rs531730856" | -1.00e+01 |
# | chr1:13289    | ["C","CCT"]                    | "rs538791886" | -1.00e+01 |
# +---------------+--------------------------------+---------------+-----------+
#
# +----------+----------------+-------------+-------------+-------------+
# | filters  | info.AF        | N06A-EUR.ES | N06A-EUR.SE | N06A-EUR.NC |
# +----------+----------------+-------------+-------------+-------------+
# | set<str> | array<float64> |     float64 |     float64 |       int64 |
# +----------+----------------+-------------+-------------+-------------+
# | {}       | [4.76e-01]     |   -1.75e-02 |    1.09e-02 |       54524 |
# | {}       | [1.27e-03]     |   -6.84e-02 |    1.54e-01 |       54524 |
# | {}       | [9.92e-01]     |    4.17e-02 |    7.30e-02 |       54524 |
# | {}       | [1.24e-01]     |    5.78e-03 |    1.86e-02 |       54524 |
# | {}       | [1.24e-01]     |    5.78e-03 |    1.86e-02 |       54524 |
# | {}       | [1.48e-02]     |   -7.19e-03 |    2.49e-02 |       54524 |
# | {}       | [5.27e-02]     |   -1.14e-03 |    1.46e-02 |       54524 |
# | {}       | [5.27e-02]     |   -1.14e-03 |    1.46e-02 |       54524 |
# | {}       | [4.54e-02]     |    4.70e-03 |    1.72e-02 |       54524 |
# | {}       | [9.98e-01]     |    5.65e-01 |    5.57e-01 |        7960 |
# +----------+----------------+-------------+-------------+-------------+
#
# +-------------+-------------+-------------+
# | N06A-EUR.SS | N06A-EUR.AF | N06A-EUR.SI |
# +-------------+-------------+-------------+
# |       int64 |     float64 |     float64 |
# +-------------+-------------+-------------+
# |      211593 |    3.99e-01 |    4.69e-01 |
# |      211593 |    1.26e-03 |    4.27e-01 |
# |      211593 |    9.94e-01 |    4.45e-01 |
# |      211593 |    8.58e-02 |    4.86e-01 |
# |      211593 |    8.58e-02 |    4.86e-01 |
# |      211593 |    5.88e-02 |    3.90e-01 |
# |      211593 |    1.89e-01 |    4.03e-01 |
# |      211593 |    1.89e-01 |    4.03e-01 |
# |      211593 |    1.34e-01 |    3.88e-01 |
# |       19121 |    9.98e-01 |    1.96e-01 |
# +-------------+-------------+-------------+
# showing top 10 rows

# %%
ss = ma.make_table()
ss.show()
# Out:
# +---------------+--------------------------------+---------------+-----------+
# | locus         | alleles                        | rsid          |      qual |
# +---------------+--------------------------------+---------------+-----------+
# | locus<GRCh38> | array<str>                     | str           |   float64 |
# +---------------+--------------------------------+---------------+-----------+
# | chr1:10177    | ["A","AC"]                     | "rs201752861" | -1.00e+01 |
# | chr1:10511    | ["G","A"]                      | "rs534229142" | -1.00e+01 |
# | chr1:10616    | ["CCGCCGTTGCAAAGGCGCGCCG","C"] | "rs376342519" | -1.00e+01 |
# | chr1:11008    | ["C","G"]                      | "rs575272151" | -1.00e+01 |
# | chr1:11012    | ["C","G"]                      | "rs544419019" | -1.00e+01 |
# | chr1:13110    | ["G","A"]                      | "rs540538026" | -1.00e+01 |
# | chr1:13116    | ["T","G"]                      | "rs62635286"  | -1.00e+01 |
# | chr1:13118    | ["A","G"]                      | "rs62028691"  | -1.00e+01 |
# | chr1:13273    | ["G","C"]                      | "rs531730856" | -1.00e+01 |
# | chr1:13289    | ["C","CCT"]                    | "rs538791886" | -1.00e+01 |
# +---------------+--------------------------------+---------------+-----------+
#
# +----------+----------------+----------------+----------------+--------------+
# | filters  | info.AF        | N06A-AFR.ES    | N06A-AFR.SE    | N06A-AFR.NC  |
# +----------+----------------+----------------+----------------+--------------+
# | set<str> | array<float64> | array<float64> | array<float64> | array<int64> |
# +----------+----------------+----------------+----------------+--------------+
# | {}       | [4.76e-01]     | [1.25e-02]     | [8.52e-02]     | [730]        |
# | {}       | [1.27e-03]     | NA             | NA             | NA           |
# | {}       | [9.92e-01]     | [-1.05e+00]    | [4.09e-01]     | [730]        |
# | {}       | [1.24e-01]     | [8.25e-03]     | [1.12e-01]     | [730]        |
# | {}       | [1.24e-01]     | [8.25e-03]     | [1.12e-01]     | [730]        |
# | {}       | [1.48e-02]     | [3.64e-02]     | [4.58e-01]     | [730]        |
# | {}       | [5.27e-02]     | [3.72e-01]     | [2.34e-01]     | [730]        |
# | {}       | [5.27e-02]     | [3.72e-01]     | [2.34e-01]     | [730]        |
# | {}       | [4.54e-02]     | [5.13e-01]     | [2.83e-01]     | [730]        |
# | {}       | [9.98e-01]     | NA             | NA             | NA           |
# +----------+----------------+----------------+----------------+--------------+
#
# +--------------+----------------+----------------+----------------+
# | N06A-AFR.SS  | N06A-AFR.AF    | N06A-AFR.SI    | N06A-AMR.ES    |
# +--------------+----------------+----------------+----------------+
# | array<int64> | array<float64> | array<float64> | array<float64> |
# +--------------+----------------+----------------+----------------+
# | [2734]       | [4.76e-01]     | [5.67e-01]     | [-4.13e-01]    |
# | NA           | NA             | NA             | NA             |
# | [2734]       | [9.93e-01]     | [7.89e-01]     | NA             |
# | [2734]       | [1.24e-01]     | [7.56e-01]     | [-5.88e-01]    |
# | [2734]       | [1.24e-01]     | [7.56e-01]     | [-5.88e-01]    |
# | [2734]       | [1.50e-02]     | [3.42e-01]     | [2.20e-01]     |
# | [2734]       | [5.08e-02]     | [3.90e-01]     | [3.05e-02]     |
# | [2734]       | [5.08e-02]     | [3.90e-01]     | [3.05e-02]     |
# | [2734]       | [4.49e-02]     | [2.94e-01]     | [2.30e-01]     |
# | NA           | NA             | NA             | NA             |
# +--------------+----------------+----------------+----------------+
#
# +----------------+--------------+--------------+----------------+
# | N06A-AMR.SE    | N06A-AMR.NC  | N06A-AMR.SS  | N06A-AMR.AF    |
# +----------------+--------------+--------------+----------------+
# | array<float64> | array<int64> | array<int64> | array<float64> |
# +----------------+--------------+--------------+----------------+
# | [2.99e-01]     | [81]         | [301]        | [4.05e-01]     |
# | NA             | NA           | NA           | NA             |
# | NA             | NA           | NA           | NA             |
# | [4.42e-01]     | [81]         | [301]        | [8.82e-02]     |
# | [4.42e-01]     | [81]         | [301]        | [8.82e-02]     |
# | [7.65e-01]     | [81]         | [301]        | [4.66e-02]     |
# | [4.51e-01]     | [81]         | [301]        | [1.54e-01]     |
# | [4.51e-01]     | [81]         | [301]        | [1.54e-01]     |
# | [5.09e-01]     | [81]         | [301]        | [1.40e-01]     |
# | NA             | NA           | NA           | NA             |
# +----------------+--------------+--------------+----------------+
#
# +----------------+----------------+----------------+--------------+
# | N06A-AMR.SI    | N06A-EAS.ES    | N06A-EAS.SE    | N06A-EAS.NC  |
# +----------------+----------------+----------------+--------------+
# | array<float64> | array<float64> | array<float64> | array<int64> |
# +----------------+----------------+----------------+--------------+
# | [4.69e-01]     | [-6.72e-01]    | [2.26e-01]     | [131]        |
# | NA             | NA             | NA             | NA           |
# | NA             | NA             | NA             | NA           |
# | [6.53e-01]     | [-3.06e-01]    | [4.06e-01]     | [131]        |
# | [6.53e-01]     | [-3.06e-01]    | [4.06e-01]     | [131]        |
# | [4.14e-01]     | [-2.29e-02]    | [1.13e+00]     | [131]        |
# | [4.19e-01]     | [-7.67e-01]    | [6.09e-01]     | [131]        |
# | [4.19e-01]     | [-7.67e-01]    | [6.09e-01]     | [131]        |
# | [3.60e-01]     | [-1.04e-01]    | [3.65e-01]     | [131]        |
# | NA             | NA             | NA             | NA           |
# +----------------+----------------+----------------+--------------+
#
# +--------------+----------------+----------------+----------------+
# | N06A-EAS.SS  | N06A-EAS.AF    | N06A-EAS.SI    | N06A-EUR.ES    |
# +--------------+----------------+----------------+----------------+
# | array<int64> | array<float64> | array<float64> | array<float64> |
# +--------------+----------------+----------------+----------------+
# | [981]        | [3.39e-01]     | [5.17e-01]     | [-1.75e-02]    |
# | NA           | NA             | NA             | [-6.84e-02]    |
# | NA           | NA             | NA             | [4.17e-02]     |
# | [981]        | [5.22e-02]     | [6.65e-01]     | [5.78e-03]     |
# | [981]        | [5.22e-02]     | [6.65e-01]     | [5.78e-03]     |
# | [981]        | [1.69e-02]     | [2.55e-01]     | [-7.19e-03]    |
# | [981]        | [5.65e-02]     | [3.06e-01]     | [-1.14e-03]    |
# | [981]        | [5.65e-02]     | [3.06e-01]     | [-1.14e-03]    |
# | [981]        | [9.92e-02]     | [4.57e-01]     | [4.70e-03]     |
# | NA           | NA             | NA             | [5.65e-01]     |
# +--------------+----------------+----------------+----------------+
#
# +----------------+--------------+--------------+----------------+
# | N06A-EUR.SE    | N06A-EUR.NC  | N06A-EUR.SS  | N06A-EUR.AF    |
# +----------------+--------------+--------------+----------------+
# | array<float64> | array<int64> | array<int64> | array<float64> |
# +----------------+--------------+--------------+----------------+
# | [1.09e-02]     | [54524]      | [211593]     | [3.99e-01]     |
# | [1.54e-01]     | [54524]      | [211593]     | [1.26e-03]     |
# | [7.30e-02]     | [54524]      | [211593]     | [9.94e-01]     |
# | [1.86e-02]     | [54524]      | [211593]     | [8.58e-02]     |
# | [1.86e-02]     | [54524]      | [211593]     | [8.58e-02]     |
# | [2.49e-02]     | [54524]      | [211593]     | [5.88e-02]     |
# | [1.46e-02]     | [54524]      | [211593]     | [1.89e-01]     |
# | [1.46e-02]     | [54524]      | [211593]     | [1.89e-01]     |
# | [1.72e-02]     | [54524]      | [211593]     | [1.34e-01]     |
# | [5.57e-01]     | [7960]       | [19121]      | [9.98e-01]     |
# +----------------+--------------+--------------+----------------+
#
# +----------------+----------------+----------------+--------------+
# | N06A-EUR.SI    | N06A-MID.ES    | N06A-MID.SE    | N06A-MID.NC  |
# +----------------+----------------+----------------+--------------+
# | array<float64> | array<float64> | array<float64> | array<int64> |
# +----------------+----------------+----------------+--------------+
# | [4.69e-01]     | [1.74e-01]     | [2.35e-01]     | [155]        |
# | [4.27e-01]     | NA             | NA             | NA           |
# | [4.45e-01]     | NA             | NA             | NA           |
# | [4.86e-01]     | [-5.62e-02]    | [3.50e-01]     | [155]        |
# | [4.86e-01]     | [-5.62e-02]    | [3.50e-01]     | [155]        |
# | [3.90e-01]     | [-9.39e-02]    | [7.13e-01]     | [155]        |
# | [4.03e-01]     | [1.72e-01]     | [3.39e-01]     | [155]        |
# | [4.03e-01]     | [1.72e-01]     | [3.39e-01]     | [155]        |
# | [3.88e-01]     | [4.27e-01]     | [3.91e-01]     | [155]        |
# | [1.96e-01]     | NA             | NA             | NA           |
# +----------------+----------------+----------------+--------------+
#
# +--------------+----------------+----------------+----------------+
# | N06A-MID.SS  | N06A-MID.AF    | N06A-MID.SI    | N06A-SAS.ES    |
# +--------------+----------------+----------------+----------------+
# | array<int64> | array<float64> | array<float64> | array<float64> |
# +--------------+----------------+----------------+----------------+
# | [532]        | [4.28e-01]     | [4.21e-01]     | [-4.74e-02]    |
# | NA           | NA             | NA             | NA             |
# | NA           | NA             | NA             | [-5.09e-02]    |
# | [532]        | [9.56e-02]     | [5.20e-01]     | [2.71e-02]     |
# | [532]        | [9.56e-02]     | [5.20e-01]     | [2.71e-02]     |
# | [532]        | [3.44e-02]     | [2.94e-01]     | [-2.14e-01]    |
# | [532]        | [1.55e-01]     | [3.83e-01]     | [-3.43e-02]    |
# | [532]        | [1.55e-01]     | [3.83e-01]     | [-3.43e-02]    |
# | [532]        | [1.13e-01]     | [3.40e-01]     | [3.42e-02]     |
# | NA           | NA             | NA             | NA             |
# +--------------+----------------+----------------+----------------+
#
# +----------------+--------------+--------------+----------------+
# | N06A-SAS.SE    | N06A-SAS.NC  | N06A-SAS.SS  | N06A-SAS.AF    |
# +----------------+--------------+--------------+----------------+
# | array<float64> | array<int64> | array<int64> | array<float64> |
# +----------------+--------------+--------------+----------------+
# | [6.96e-02]     | [1479]       | [5027]       | [4.34e-01]     |
# | NA             | NA           | NA           | NA             |
# | [6.29e-01]     | [1479]       | [5027]       | [9.96e-01]     |
# | [1.32e-01]     | [1479]       | [5027]       | [7.43e-02]     |
# | [1.32e-01]     | [1479]       | [5027]       | [7.43e-02]     |
# | [1.84e-01]     | [1479]       | [5027]       | [4.37e-02]     |
# | [9.90e-02]     | [1479]       | [5027]       | [1.61e-01]     |
# | [9.90e-02]     | [1479]       | [5027]       | [1.61e-01]     |
# | [1.11e-01]     | [1479]       | [5027]       | [1.28e-01]     |
# | NA             | NA           | NA           | NA             |
# +----------------+--------------+--------------+----------------+
#
# +----------------+----------------+----------------+--------------+
# | N06A-SAS.SI    | N06AA-AFR.ES   | N06AA-AFR.SE   | N06AA-AFR.NC |
# +----------------+----------------+----------------+--------------+
# | array<float64> | array<float64> | array<float64> | array<int64> |
# +----------------+----------------+----------------+--------------+
# | [4.52e-01]     | [4.43e-02]     | [9.59e-02]     | [521]        |
# | NA             | NA             | NA             | NA           |
# | [3.54e-01]     | [-3.47e-01]    | [4.18e-01]     | [521]        |
# | [4.61e-01]     | [6.88e-02]     | [1.26e-01]     | [521]        |
# | [4.61e-01]     | [6.88e-02]     | [1.26e-01]     | [521]        |
# | [3.93e-01]     | [2.40e-01]     | [4.93e-01]     | [521]        |
# | [4.07e-01]     | [-1.87e-02]    | [2.64e-01]     | [521]        |
# | [4.07e-01]     | [-1.87e-02]    | [2.64e-01]     | [521]        |
# | [3.87e-01]     | [4.64e-01]     | [3.16e-01]     | [521]        |
# | NA             | NA             | NA             | NA           |
# +----------------+----------------+----------------+--------------+
#
# +--------------+----------------+----------------+----------------+
# | N06AA-AFR.SS | N06AA-AFR.AF   | N06AA-AFR.SI   | N06AA-EUR.ES   |
# +--------------+----------------+----------------+----------------+
# | array<int64> | array<float64> | array<float64> | array<float64> |
# +--------------+----------------+----------------+----------------+
# | [2734]       | [4.76e-01]     | [5.67e-01]     | [-2.63e-02]    |
# | NA           | NA             | NA             | [-9.22e-02]    |
# | [2734]       | [9.92e-01]     | [7.89e-01]     | [1.03e-01]     |
# | [2734]       | [1.24e-01]     | [7.56e-01]     | [-1.61e-03]    |
# | [2734]       | [1.24e-01]     | [7.56e-01]     | [-1.61e-03]    |
# | [2734]       | [1.48e-02]     | [3.42e-01]     | [-2.83e-02]    |
# | [2734]       | [5.27e-02]     | [3.90e-01]     | [-2.11e-03]    |
# | [2734]       | [5.27e-02]     | [3.90e-01]     | [-2.11e-03]    |
# | [2734]       | [4.54e-02]     | [2.94e-01]     | [3.29e-02]     |
# | NA           | NA             | NA             | [7.64e-01]     |
# +--------------+----------------+----------------+----------------+
#
# +----------------+--------------+--------------+----------------+
# | N06AA-EUR.SE   | N06AA-EUR.NC | N06AA-EUR.SS | N06AA-EUR.AF   |
# +----------------+--------------+--------------+----------------+
# | array<float64> | array<int64> | array<int64> | array<float64> |
# +----------------+--------------+--------------+----------------+
# | [1.25e-02]     | [36034]      | [211593]     | [3.99e-01]     |
# | [1.77e-01]     | [36034]      | [211593]     | [1.26e-03]     |
# | [8.37e-02]     | [36034]      | [211593]     | [9.94e-01]     |
# | [2.15e-02]     | [36034]      | [211593]     | [8.59e-02]     |
# | [2.15e-02]     | [36034]      | [211593]     | [8.59e-02]     |
# | [2.86e-02]     | [36034]      | [211593]     | [5.88e-02]     |
# | [1.69e-02]     | [36034]      | [211593]     | [1.89e-01]     |
# | [1.69e-02]     | [36034]      | [211593]     | [1.89e-01]     |
# | [1.98e-02]     | [36034]      | [211593]     | [1.34e-01]     |
# | [6.37e-01]     | [4545]       | [19121]      | [9.98e-01]     |
# +----------------+--------------+--------------+----------------+
#
# +----------------+----------------+----------------+--------------+
# | N06AA-EUR.SI   | N06AA-MID.ES   | N06AA-MID.SE   | N06AA-MID.NC |
# +----------------+----------------+----------------+--------------+
# | array<float64> | array<float64> | array<float64> | array<int64> |
# +----------------+----------------+----------------+--------------+
# | [4.69e-01]     | [4.84e-03]     | [2.57e-01]     | [113]        |
# | [4.27e-01]     | NA             | NA             | NA           |
# | [4.45e-01]     | NA             | NA             | NA           |
# | [4.86e-01]     | [-2.85e-02]    | [3.85e-01]     | [113]        |
# | [4.86e-01]     | [-2.85e-02]    | [3.85e-01]     | [113]        |
# | [3.90e-01]     | [4.73e-01]     | [7.61e-01]     | [113]        |
# | [4.03e-01]     | [5.04e-02]     | [3.81e-01]     | [113]        |
# | [4.03e-01]     | [5.04e-02]     | [3.81e-01]     | [113]        |
# | [3.88e-01]     | [2.13e-01]     | [4.41e-01]     | [113]        |
# | [1.96e-01]     | NA             | NA             | NA           |
# +----------------+----------------+----------------+--------------+
#
# +--------------+----------------+----------------+----------------+
# | N06AA-MID.SS | N06AA-MID.AF   | N06AA-MID.SI   | N06AA-SAS.ES   |
# +--------------+----------------+----------------+----------------+
# | array<int64> | array<float64> | array<float64> | array<float64> |
# +--------------+----------------+----------------+----------------+
# | [532]        | [4.25e-01]     | [4.21e-01]     | [-3.33e-02]    |
# | NA           | NA             | NA             | NA             |
# | NA           | NA             | NA             | [-3.57e-01]    |
# | [532]        | [9.60e-02]     | [5.20e-01]     | [9.43e-03]     |
# | [532]        | [9.60e-02]     | [5.20e-01]     | [9.43e-03]     |
# | [532]        | [3.36e-02]     | [2.94e-01]     | [-2.36e-01]    |
# | [532]        | [1.57e-01]     | [3.83e-01]     | [-6.69e-02]    |
# | [532]        | [1.57e-01]     | [3.83e-01]     | [-6.69e-02]    |
# | [532]        | [1.17e-01]     | [3.40e-01]     | [9.89e-03]     |
# | NA           | NA             | NA             | NA             |
# +--------------+----------------+----------------+----------------+
#
# +----------------+--------------+--------------+----------------+
# | N06AA-SAS.SE   | N06AA-SAS.NC | N06AA-SAS.SS | N06AA-SAS.AF   |
# +----------------+--------------+--------------+----------------+
# | array<float64> | array<int64> | array<int64> | array<float64> |
# +----------------+--------------+--------------+----------------+
# | [7.69e-02]     | [1069]       | [5027]       | [4.34e-01]     |
# | NA             | NA           | NA           | NA             |
# | [6.74e-01]     | [1069]       | [5027]       | [9.96e-01]     |
# | [1.47e-01]     | [1069]       | [5027]       | [7.46e-02]     |
# | [1.47e-01]     | [1069]       | [5027]       | [7.46e-02]     |
# | [2.03e-01]     | [1069]       | [5027]       | [4.37e-02]     |
# | [1.09e-01]     | [1069]       | [5027]       | [1.61e-01]     |
# | [1.09e-01]     | [1069]       | [5027]       | [1.61e-01]     |
# | [1.23e-01]     | [1069]       | [5027]       | [1.29e-01]     |
# | NA             | NA           | NA           | NA             |
# +----------------+--------------+--------------+----------------+
#
# +----------------+----------------+----------------+--------------+
# | N06AA-SAS.SI   | N06AB-AFR.ES   | N06AB-AFR.SE   | N06AB-AFR.NC |
# +----------------+----------------+----------------+--------------+
# | array<float64> | array<float64> | array<float64> | array<int64> |
# +----------------+----------------+----------------+--------------+
# | [4.52e-01]     | [-1.27e-02]    | [1.11e-01]     | [357]        |
# | NA             | NA             | NA             | NA           |
# | [3.54e-01]     | [-9.34e-01]    | [5.28e-01]     | [357]        |
# | [4.61e-01]     | [7.69e-02]     | [1.46e-01]     | [357]        |
# | [4.61e-01]     | [7.69e-02]     | [1.46e-01]     | [357]        |
# | [3.93e-01]     | [-4.90e-01]    | [5.62e-01]     | [357]        |
# | [4.07e-01]     | [6.05e-01]     | [3.07e-01]     | [357]        |
# | [4.07e-01]     | [6.05e-01]     | [3.07e-01]     | [357]        |
# | [3.87e-01]     | [4.12e-01]     | [3.63e-01]     | [357]        |
# | NA             | NA             | NA             | NA           |
# +----------------+----------------+----------------+--------------+
#
# +--------------+----------------+----------------+----------------+
# | N06AB-AFR.SS | N06AB-AFR.AF   | N06AB-AFR.SI   | N06AB-EUR.ES   |
# +--------------+----------------+----------------+----------------+
# | array<int64> | array<float64> | array<float64> | array<float64> |
# +--------------+----------------+----------------+----------------+
# | [2734]       | [4.78e-01]     | [5.67e-01]     | [-8.88e-03]    |
# | NA           | NA             | NA             | [-1.10e-01]    |
# | [2734]       | [9.92e-01]     | [7.89e-01]     | [1.70e-02]     |
# | [2734]       | [1.24e-01]     | [7.56e-01]     | [1.05e-02]     |
# | [2734]       | [1.24e-01]     | [7.56e-01]     | [1.05e-02]     |
# | [2734]       | [1.53e-02]     | [3.42e-01]     | [1.22e-02]     |
# | [2734]       | [5.13e-02]     | [3.90e-01]     | [-9.32e-03]    |
# | [2734]       | [5.13e-02]     | [3.90e-01]     | [-9.32e-03]    |
# | [2734]       | [4.57e-02]     | [2.94e-01]     | [-9.41e-03]    |
# | NA           | NA             | NA             | [-2.22e-01]    |
# +--------------+----------------+----------------+----------------+
#
# +----------------+--------------+--------------+----------------+
# | N06AB-EUR.SE   | N06AB-EUR.NC | N06AB-EUR.SS | N06AB-EUR.AF   |
# +----------------+--------------+--------------+----------------+
# | array<float64> | array<int64> | array<int64> | array<float64> |
# +----------------+--------------+--------------+----------------+
# | [1.30e-02]     | [32332]      | [211593]     | [3.99e-01]     |
# | [1.83e-01]     | [32332]      | [211593]     | [1.26e-03]     |
# | [8.75e-02]     | [32332]      | [211593]     | [9.94e-01]     |
# | [2.24e-02]     | [32332]      | [211593]     | [8.58e-02]     |
# | [2.24e-02]     | [32332]      | [211593]     | [8.58e-02]     |
# | [2.98e-02]     | [32332]      | [211593]     | [5.87e-02]     |
# | [1.76e-02]     | [32332]      | [211593]     | [1.90e-01]     |
# | [1.76e-02]     | [32332]      | [211593]     | [1.90e-01]     |
# | [2.06e-02]     | [32332]      | [211593]     | [1.34e-01]     |
# | [6.38e-01]     | [4845]       | [19121]      | [9.98e-01]     |
# +----------------+--------------+--------------+----------------+
#
# +----------------+----------------+----------------+--------------+
# | N06AB-EUR.SI   | N06AB-MID.ES   | N06AB-MID.SE   | N06AB-MID.NC |
# +----------------+----------------+----------------+--------------+
# | array<float64> | array<float64> | array<float64> | array<int64> |
# +----------------+----------------+----------------+--------------+
# | [4.69e-01]     | [2.01e-01]     | [2.80e-01]     | [88]         |
# | [4.27e-01]     | NA             | NA             | NA           |
# | [4.45e-01]     | NA             | NA             | NA           |
# | [4.86e-01]     | [-1.67e-01]    | [4.05e-01]     | [88]         |
# | [4.86e-01]     | [-1.67e-01]    | [4.05e-01]     | [88]         |
# | [3.90e-01]     | [2.67e-01]     | [8.71e-01]     | [88]         |
# | [4.03e-01]     | [3.03e-01]     | [4.07e-01]     | [88]         |
# | [4.03e-01]     | [3.03e-01]     | [4.07e-01]     | [88]         |
# | [3.88e-01]     | [3.12e-01]     | [4.52e-01]     | [88]         |
# | [1.96e-01]     | NA             | NA             | NA           |
# +----------------+----------------+----------------+--------------+
#
# +--------------+----------------+----------------+----------------+
# | N06AB-MID.SS | N06AB-MID.AF   | N06AB-MID.SI   | N06AB-SAS.ES   |
# +--------------+----------------+----------------+----------------+
# | array<int64> | array<float64> | array<float64> | array<float64> |
# +--------------+----------------+----------------+----------------+
# | [532]        | [4.26e-01]     | [4.21e-01]     | [1.21e-01]     |
# | NA           | NA             | NA             | NA             |
# | NA           | NA             | NA             | [1.34e+00]     |
# | [532]        | [9.61e-02]     | [5.20e-01]     | [-2.17e-01]    |
# | [532]        | [9.61e-02]     | [5.20e-01]     | [-2.17e-01]    |
# | [532]        | [3.51e-02]     | [2.94e-01]     | [4.12e-02]     |
# | [532]        | [1.53e-01]     | [3.83e-01]     | [5.47e-03]     |
# | [532]        | [1.53e-01]     | [3.83e-01]     | [5.47e-03]     |
# | [532]        | [1.14e-01]     | [3.40e-01]     | [1.13e-01]     |
# | NA           | NA             | NA             | NA             |
# +--------------+----------------+----------------+----------------+
#
# +----------------+--------------+--------------+----------------+
# | N06AB-SAS.SE   | N06AB-SAS.NC | N06AB-SAS.SS | N06AB-SAS.AF   |
# +----------------+--------------+--------------+----------------+
# | array<float64> | array<int64> | array<int64> | array<float64> |
# +----------------+--------------+--------------+----------------+
# | [9.18e-02]     | [731]        | [5027]       | [4.32e-01]     |
# | NA             | NA           | NA           | NA             |
# | [8.45e-01]     | [731]        | [5027]       | [9.95e-01]     |
# | [1.70e-01]     | [731]        | [5027]       | [7.48e-02]     |
# | [1.70e-01]     | [731]        | [5027]       | [7.48e-02]     |
# | [2.34e-01]     | [731]        | [5027]       | [4.27e-02]     |
# | [1.29e-01]     | [731]        | [5027]       | [1.61e-01]     |
# | [1.29e-01]     | [731]        | [5027]       | [1.61e-01]     |
# | [1.45e-01]     | [731]        | [5027]       | [1.28e-01]     |
# | NA             | NA           | NA           | NA             |
# +----------------+--------------+--------------+----------------+
#
# +----------------+----------------+----------------+--------------+
# | N06AB-SAS.SI   | N06AX-AFR.ES   | N06AX-AFR.SE   | N06AX-AFR.NC |
# +----------------+----------------+----------------+--------------+
# | array<float64> | array<float64> | array<float64> | array<int64> |
# +----------------+----------------+----------------+--------------+
# | [4.52e-01]     | [2.40e-01]     | [1.87e-01]     | [115]        |
# | NA             | NA             | NA             | NA           |
# | [3.54e-01]     | [-2.82e-01]    | [8.56e-01]     | [115]        |
# | [4.61e-01]     | [-4.83e-02]    | [2.49e-01]     | [115]        |
# | [4.61e-01]     | [-4.83e-02]    | [2.49e-01]     | [115]        |
# | [3.93e-01]     | [-2.61e-01]    | [9.47e-01]     | [115]        |
# | [4.07e-01]     | [8.92e-02]     | [4.90e-01]     | [115]        |
# | [4.07e-01]     | [8.92e-02]     | [4.90e-01]     | [115]        |
# | [3.87e-01]     | [8.75e-01]     | [5.88e-01]     | [115]        |
# | NA             | NA             | NA             | NA           |
# +----------------+----------------+----------------+--------------+
#
# +--------------+----------------+----------------+----------------+
# | N06AX-AFR.SS | N06AX-AFR.AF   | N06AX-AFR.SI   | N06AX-EUR.ES   |
# +--------------+----------------+----------------+----------------+
# | array<int64> | array<float64> | array<float64> | array<float64> |
# +--------------+----------------+----------------+----------------+
# | [2734]       | [4.76e-01]     | [5.67e-01]     | [-3.47e-02]    |
# | NA           | NA             | NA             | [-2.85e-01]    |
# | [2734]       | [9.92e-01]     | [7.89e-01]     | [-7.87e-02]    |
# | [2734]       | [1.25e-01]     | [7.56e-01]     | [3.07e-02]     |
# | [2734]       | [1.25e-01]     | [7.56e-01]     | [3.07e-02]     |
# | [2734]       | [1.52e-02]     | [3.42e-01]     | [-1.59e-02]    |
# | [2734]       | [5.27e-02]     | [3.90e-01]     | [-5.73e-02]    |
# | [2734]       | [5.27e-02]     | [3.90e-01]     | [-5.73e-02]    |
# | [2734]       | [4.60e-02]     | [2.94e-01]     | [-8.41e-03]    |
# | NA           | NA             | NA             | NA             |
# +--------------+----------------+----------------+----------------+
#
# +----------------+--------------+--------------+----------------+
# | N06AX-EUR.SE   | N06AX-EUR.NC | N06AX-EUR.SS | N06AX-EUR.AF   |
# +----------------+--------------+--------------+----------------+
# | array<float64> | array<int64> | array<int64> | array<float64> |
# +----------------+--------------+--------------+----------------+
# | [2.25e-02]     | [9396]       | [211593]     | [3.99e-01]     |
# | [3.20e-01]     | [9396]       | [211593]     | [1.27e-03]     |
# | [1.50e-01]     | [9396]       | [211593]     | [9.94e-01]     |
# | [3.84e-02]     | [9396]       | [211593]     | [8.59e-02]     |
# | [3.84e-02]     | [9396]       | [211593]     | [8.59e-02]     |
# | [5.13e-02]     | [9396]       | [211593]     | [5.87e-02]     |
# | [3.02e-02]     | [9396]       | [211593]     | [1.90e-01]     |
# | [3.02e-02]     | [9396]       | [211593]     | [1.90e-01]     |
# | [3.54e-02]     | [9396]       | [211593]     | [1.34e-01]     |
# | NA             | NA           | NA           | NA             |
# +----------------+--------------+--------------+----------------+
#
# +----------------+----------------+----------------+--------------+
# | N06AX-EUR.SI   | N06AX-SAS.ES   | N06AX-SAS.SE   | N06AX-SAS.NC |
# +----------------+----------------+----------------+--------------+
# | array<float64> | array<float64> | array<float64> | array<int64> |
# +----------------+----------------+----------------+--------------+
# | [4.69e-01]     | [5.76e-03]     | [1.47e-01]     | [239]        |
# | [4.27e-01]     | NA             | NA             | NA           |
# | [4.45e-01]     | [8.22e-01]     | [1.45e+00]     | [239]        |
# | [4.86e-01]     | [-8.05e-02]    | [2.68e-01]     | [239]        |
# | [4.86e-01]     | [-8.05e-02]    | [2.68e-01]     | [239]        |
# | [3.90e-01]     | [-3.19e-01]    | [3.80e-01]     | [239]        |
# | [4.03e-01]     | [1.65e-01]     | [2.05e-01]     | [239]        |
# | [4.03e-01]     | [1.65e-01]     | [2.05e-01]     | [239]        |
# | [3.88e-01]     | [-9.82e-04]    | [2.32e-01]     | [239]        |
# | NA             | NA             | NA             | NA           |
# +----------------+----------------+----------------+--------------+
#
# +--------------+----------------+----------------+
# | N06AX-SAS.SS | N06AX-SAS.AF   | N06AX-SAS.SI   |
# +--------------+----------------+----------------+
# | array<int64> | array<float64> | array<float64> |
# +--------------+----------------+----------------+
# | [5027]       | [4.33e-01]     | [4.52e-01]     |
# | NA           | NA             | NA             |
# | [5027]       | [9.96e-01]     | [3.54e-01]     |
# | [5027]       | [7.41e-02]     | [4.61e-01]     |
# | [5027]       | [7.41e-02]     | [4.61e-01]     |
# | [5027]       | [4.32e-02]     | [3.93e-01]     |
# | [5027]       | [1.60e-01]     | [4.07e-01]     |
# | [5027]       | [1.60e-01]     | [4.07e-01]     |
# | [5027]       | [1.29e-01]     | [3.87e-01]     |
# | NA           | NA             | NA             |
# +--------------+----------------+----------------+
# showing top 10 rows
